# %%
import keras

# %%
from keras.models import Sequential
obj=Sequential()

# %%
from keras.layers import Dense

# %%
import pandas as pd
dt=pd.read_csv("/content/heart (1).csv")

# %%
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dt.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
dt = dt.drop(['chol','fbs'],axis=1)

# %%
x=dt.iloc[:,0:11]
y=dt['target']

# %%
x
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      52    1   0       125        1      168      0      1.0      2   2
# 1      53    1   0       140        0      155      1      3.1      0   0
# 2      70    1   0       145        1      125      1      2.6      0   0
# 3      61    1   0       148        1      161      0      0.0      2   1
# 4      62    0   0       138        1      106      0      1.9      1   3
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 1020   59    1   1       140        1      164      1      0.0      2   0
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 1022   47    1   0       110        0      118      1      1.0      1   1
# 1023   50    0   0       110        0      159      0      0.0      2   0
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
# ...    ...
# 1020     2
# 1021     3
# 1022     2
# 1023     2
# 1024     3
#
# [1025 rows x 11 columns]

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1025, 11) (1025,) (820, 11) (205, 11) (820,) (205,)

# %%
obj.add(Dense(units=11,activation='relu'))

# %%
obj.add(Dense(units=5,activation='relu'))

# %%
obj.add(Dense(units=1,activation='sigmoid'))

# %%
obj.build(input_shape=(None,11))

# %%
obj.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198 (792.00 B)
#  Trainable params: 198 (792.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
obj.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
obj.fit(x_train,y_train,epochs=100,batch_size=8,steps_per_epoch=x_train.shape[0]//8)
# Out:
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4456 - loss: 12.7716
# Epoch 2/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 229us/step - accuracy: 0.7500 - loss: 1.9094
# Epoch 3/100
#  77/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5819 - loss: 1.5929
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5871 - loss: 1.5369
# Epoch 4/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 213us/step - accuracy: 0.5000 - loss: 0.5908
# Epoch 5/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6073 - loss: 0.9663
# Epoch 6/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.5000 - loss: 1.4896
# Epoch 7/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6508 - loss: 0.7514
# Epoch 8/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 226us/step - accuracy: 1.0000 - loss: 0.2381
# Epoch 9/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7189 - loss: 0.5956
# Epoch 10/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - accuracy: 0.5000 - loss: 0.8212
# Epoch 11/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7626 - loss: 0.5126
# Epoch 12/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.7500 - loss: 0.5927
# Epoch 13/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8055 - loss: 0.4484
# Epoch 14/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 224us/step - accuracy: 0.7500 - loss: 0.8230
# Epoch 15/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7871 - loss: 0.4601
# Epoch 16/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - accuracy: 0.7500 - loss: 0.3138
# Epoch 17/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7856 - loss: 0.4644
# Epoch 18/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step - accuracy: 1.0000 - loss: 0.2278
# Epoch 19/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8174 - loss: 0.4288
# Epoch 20/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 1.0000 - loss: 0.2736
# Epoch 21/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7973 - loss: 0.4322
# Epoch 22/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.5000 - loss: 0.6200
# Epoch 23/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7662 - loss: 0.5194
# Epoch 24/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 1.0000 - loss: 0.2399
# Epoch 25/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8080 - loss: 0.4349
# Epoch 26/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step - accuracy: 0.5000 - loss: 0.5014
# Epoch 27/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8310 - loss: 0.3975
# Epoch 28/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - accuracy: 0.7500 - loss: 0.7367
# Epoch 29/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8064 - loss: 0.4300
# Epoch 30/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - accuracy: 1.0000 - loss: 0.1433
# Epoch 31/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7811 - loss: 0.5098
# Epoch 32/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - accuracy: 1.0000 - loss: 0.2729
# Epoch 33/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8533 - loss: 0.3613
# Epoch 34/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - accuracy: 0.2500 - loss: 1.2762
# Epoch 35/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8133 - loss: 0.4026
# Epoch 36/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - accuracy: 0.7500 - loss: 0.3922
# Epoch 37/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8159 - loss: 0.3944
# Epoch 38/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 224us/step - accuracy: 1.0000 - loss: 0.0890
# Epoch 39/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.3505
# Epoch 40/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 221us/step - accuracy: 0.5000 - loss: 0.5807
# Epoch 41/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.3928
# Epoch 42/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 222us/step - accuracy: 1.0000 - loss: 0.1550
# Epoch 43/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8162 - loss: 0.3981
# Epoch 44/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 1.0000 - loss: 0.1916
# Epoch 45/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8217 - loss: 0.4071
# Epoch 46/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7500 - loss: 0.4484
# Epoch 47/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8445 - loss: 0.3973
# Epoch 48/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - accuracy: 1.0000 - loss: 0.2806
# Epoch 49/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8215 - loss: 0.3818
# Epoch 50/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - accuracy: 0.7500 - loss: 0.6442
# Epoch 51/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8215 - loss: 0.3936
# Epoch 52/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 225us/step - accuracy: 1.0000 - loss: 0.2169
# Epoch 53/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7959 - loss: 0.4254
# Epoch 54/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - accuracy: 1.0000 - loss: 0.1868
# Epoch 55/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8076 - loss: 0.4515
# Epoch 56/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.7500 - loss: 0.2759
# Epoch 57/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8404 - loss: 0.3753
# Epoch 58/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - accuracy: 0.7500 - loss: 0.5600
# Epoch 59/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8196 - loss: 0.3797
# Epoch 60/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - accuracy: 1.0000 - loss: 0.2082
# Epoch 61/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8637 - loss: 0.3286
# Epoch 62/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step - accuracy: 1.0000 - loss: 0.1746
# Epoch 63/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7619 - loss: 0.4878
# Epoch 64/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step - accuracy: 0.7500 - loss: 0.3923
# Epoch 65/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8341 - loss: 0.3749
# Epoch 66/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - accuracy: 0.7500 - loss: 0.8779
# Epoch 67/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8298 - loss: 0.3505
# Epoch 68/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 241us/step - accuracy: 1.0000 - loss: 0.1112
# Epoch 69/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.4180
# Epoch 70/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - accuracy: 1.0000 - loss: 0.1520
# Epoch 71/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8320 - loss: 0.3796
# Epoch 72/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.5000 - loss: 0.6930
# Epoch 73/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8016 - loss: 0.4300
# Epoch 74/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.7500 - loss: 0.3605
# Epoch 75/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8252 - loss: 0.3675
# Epoch 76/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 77/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8595 - loss: 0.3670
# Epoch 78/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.7500 - loss: 0.3494
# Epoch 79/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8154 - loss: 0.3808
# Epoch 80/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 232us/step - accuracy: 0.7500 - loss: 0.3333
# Epoch 81/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8427 - loss: 0.3617
# Epoch 82/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 217us/step - accuracy: 0.7500 - loss: 0.1958
# Epoch 83/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8321 - loss: 0.3727
# Epoch 84/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - accuracy: 1.0000 - loss: 0.0741
# Epoch 85/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8434 - loss: 0.4073
# Epoch 86/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - accuracy: 1.0000 - loss: 0.1410
# Epoch 87/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8512 - loss: 0.3565
# Epoch 88/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - accuracy: 0.7500 - loss: 0.4782
# Epoch 89/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8077 - loss: 0.4607
# Epoch 90/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - accuracy: 1.0000 - loss: 0.1125
# Epoch 91/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.3856
# Epoch 92/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - accuracy: 0.7500 - loss: 0.2522
# Epoch 93/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8430 - loss: 0.3779
# Epoch 94/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 223us/step - accuracy: 0.7500 - loss: 0.2451
# Epoch 95/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8067 - loss: 0.4322
# Epoch 96/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.7500 - loss: 0.2189
# Epoch 97/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8324 - loss: 0.4051
# Epoch 98/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.5000 - loss: 0.9548
# Epoch 99/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8401 - loss: 0.3785
# Epoch 100/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - accuracy: 0.7500 - loss: 0.8098

# %%
y_pred=obj.predict(x_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_pred=(y_pred>0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8585365853658536

# %%
obj.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 588    61    0   0       145        0      146      1      1.0      1   0
# 573    44    1   0       112        0      153      0      0.0      2   1
# 668    29    1   1       130        0      202      0      0.0      2   0
# 24     42    0   2       120        1      173      0      0.0      1   0
# 447    55    1   0       160        0      145      1      0.8      1   1
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 558    39    0   2        94        1      179      0      0.0      2   0
# 749    58    1   1       125        1      144      0      0.4      1   4
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 697    67    1   2       152        0      150      0      0.8      1   0
# 722    67    0   2       152        1      172      0      0.0      2   1
#
#       thal
# 588      3
# 573      2
# 668      2
# 24       2
# 447      3
# ...    ...
# 558      2
# 749      3
# 1021     3
# 697      3
# 722      2
#
# [820 rows x 11 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')
